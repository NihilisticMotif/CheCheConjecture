# %% [markdown]
# <a href="https://colab.research.google.com/github/NihilisticMotif/CheCheConjecture/blob/main/RealAnalysis/Calculus_BC_Limit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Introduction
#
# The purpose of this project is to learn about basic concept in calculus 1 without formal proof.
# 1. Limit
# 2. Property of Limit
# 3. Indeterminate Form
# 4. Common way to solve Limit
# 5. Continuous Function
# 6. Discontinuity
# 7. Uniform Continuity

# %% [markdown]
# #Definition

# %% [markdown]
# ##What is Function ?
#
# Function is the map between 2 sets which are domain (input set) and range (output set) such that
# * $f\,:X\to Y$
# * $\forall x\in X\,:f(x)\in Y$
#
# ###Example No.1
#
# Define
# * $\vec{v}=(x_1,x_2,x_3,x_4)$
#
# $\vec{v}$ map $\{1,2,3,4\}$ with $F$
# * $\vec{v}(1)=x_1$
# * $\vec{v}(2)=x_2$
# * $\vec{v}(3)=x_3$
# * $\vec{v}(4)=x_4$
#
# In general
# * $\hat{F}\subset F$
# * $\vec{v}\,:\{1,2,3,4\}\to \hat{F}$
#
# ###Example No.2
#
# Define
# * $f(x)=x^2$
#
# $f(x)$ map $\mathbb{C}$ with $\mathbb{C}$
# * $i^2=-1$
# * $a,b\in\mathbb{R}$
# * $f(a+bi)=a^2-b^2+2abi$

# %% [markdown]
# ##What is Limit ?
#
# Limit means "approach". The limit of $x$ to $a$ means that the value of $x$ approach to $a$ such that
# * $\lim_{x\to a}f(x)=L$
#
# Such that
# * $\exists\delta>0$
# * $\forall\epsilon>0$
# * $|x-a|<\delta\implies |f(x)-L|<\epsilon$
#
# This statement means that the value of $x$ is very close to $a$ such that the different between $x$ and $a$ is nearly $0$
# * $\lim_{x\to a}x-a=0$
#
# However, in many case $f(x)$ where $x$ approach $a$ and $f(a)$ give the different output
# * $\exists f\in$ Function $\,:\lim_{x\to a}f(x)\neq f(a)$
#
# And in some case the limit of the function does not exists.
# * $\exists f\in$ Function$\,:f(x)=\emptyset$
# * $\exists f\in$ Function$\,:\lim_{x\to a}f(x)=\emptyset$
#
# Note that if
# * $\delta>0\,:f(a+\delta)\not\approx f(a-\delta)\implies \lim_{x\to0}f(a+x)=\emptyset$
# * $\lim_{x\to0^+}f(a+x)\neq \lim_{x\to0^-}f(a+x)\implies \lim_{x\to0}f(a+x)=\emptyset$
# * $\lim_{x\to a}f(x)=\pm\infty\implies\lim_{x\to a}f(x)=\emptyset$
#
# Reference
# * https://brilliant.org/wiki/limits-of-functions/

# %% [markdown]
# ##Rule of Limit
#
# Here is the rule of limit.
#
# Suppose that
# * $f(x)$ and $g(x)$ are both continuous function
# * $\lim_{x\to a}f(x)=F$
# * $\lim_{x\to a}g(x)=G$
# * $c\in \mathbb{R}$
#
# $1^{\text{st}}$ Statement
#
# Sum of 2 Limits
# * $\lim_{x\to a}f(x)+g(x)=F+G$
#
# $2^{\text{nd}}$ Statement
#
# Limit multiplied by constant
# * $\lim_{x\to a}cf(x)=cF$
#
# $3^{\text{rd}}$ Statement
#
# Product of 2 Limit
# * $\lim_{x\to a}f(x)g(x)=FG$
#
# $4^{\text{th}}$ Statement
#
# Limit division
# * $\lim_{x\to a}\frac{f(x)}{g(x)}=\frac{F}{G}\iff G\neq0$
#
# $5^{\text{th}}$ Statement
#
# Limit power
# * $\forall n\in\mathbb{N}\,:\lim_{x\to a}f(x)^n=F^n$
#
# $6^{\text{th}}$ Statement
#
# Limit Odd Root
# * $\forall n\in\{2z+1|z\in\mathbb{Z}\}\,:\lim_{x\to a}f(x)^\frac{1}{n}=F^\frac{1}{n}$
#
# $7^{\text{th}}$ Statement
#
# Limit Even Root
# * $\forall n\in\{2z|z\in\mathbb{Z}\}\,:\lim_{x\to a}f(x)^\frac{1}{n}=F^\frac{1}{n}\iff F\geq 0$
#
# Note that because limit have those properties, sets of all the function with the real and complex number are also the vector space that have infinite uncountable dimension. The discipline that study infinite dimensional vector space is called "Functional Analysis".
#
# Reference
# * Limit Laws
# * https://www.utrgv.edu/cstem/utrgv-calculus/limits/limit-laws/index.htm

# %% [markdown]
# ##What is Indeterminate Form ?
#
# Indeterminate Form is the mathematical expression that cannot compute meaningful result with only direct substitution.
#
# On the other hands, the Determinate Form is the mathematical expression can compute the result as real number, complex number or infinity.
#
# $1^{\text{st}}$ Example of Determinate Form
#
# * $\lim_{x\to a}f(x)=0$
# * $\lim_{x\to a}g(x)=0$
#
# Then
# * $\lim_{x\to a}f(x)\cdot g(x)=0$
# * $0\cdot 0=0$
#
# $2^{\text{nd}}$ Example of Determinate Form
#
# * $\lim_{x\to a}f(x)=\infty$
# * $\lim_{x\to a}g(x)=0$
#
# Because
# * $\lim_{x\to0^+}\frac{1}{x}=\infty$
#
# Then
# * $\lim_{x\to a}\frac{f(x)}{g(x)}=\infty\cdot\infty$
# * $\frac{\infty}{0}=\infty$
#
# $1^{\text{st}}$ Example of Indeterminate Form
#
# * $\lim_{x\to a}f(x)=0$
# * $\lim_{x\to a}g(x)=0$
#
# Then
# * $\lim_{x\to a}\frac{f(x)}{g(x)}=\,?$
# * $\frac{0}{0}$
#
# $2^{\text{nd}}$ Example of Indeterminate Form
#
# * $\lim_{x\to a}f(x)=\infty$
# * $\lim_{x\to a}g(x)=0$
#
# Then
# * $\lim_{x\to a}f(x)\cdot g(x)=\,?$
# * $0\cdot\infty$
#
# Reference
# 1. Indeterminate Forms by BriTheMathGuy
# * This video is about list of indeterminate forms and how to solve them.
# * https://youtu.be/oEEXnyupzdo?si=SYpOVSolhH26PRK2
# 2. Indeterminate Form & L'Hôpital's Rule
# * This website have additional lists of indeterminate and determinate forms.
# * https://www.sfu.ca/math-coursenotes/Math%20157%20Course%20Notes/sec_Hopital.html

# %% [markdown]
# ##Common Technique to Solve Limit
#
# $1^{\text{st}}$ Method: L'Hospital Rule
#
# * $\lim_{x\to a}\frac{f(x)}{g(x)}=\lim_{x\to a}\frac{f'(x)}{g'(x)}$
#
# $2^{\text{nd}}$ Method: Factoring
#
# * If: $f(x)=g(x)k(x)$
# * $\lim_{x\to a}\frac{f(x)}{g(x)}=\lim_{x\to a}\frac{g(x)k(x)}{g(x)}=k(x)$
#
# $3^{\text{rd}}$ Method: Substitution
#
# $4^{\text{th}}$ Method: Trigonometric Identity

# %% [markdown]
# #Limit Exercise Part 1: Limit Approach $a$

# %% [markdown]
# ##Exercise No.1
#
# * $f(x)=\begin{Bmatrix}
# f(1)=0\\
# \forall x\in\mathbb{R}-1\,:f(x)=x
# \end{Bmatrix}$
#
# Find
# * $\lim_{x\to 1}f(x)=\,?$

# %% [markdown]
# ###Solution
#
# Calculate $\lim_{x\to 1}f(x)$
# * $f(1+\delta)=1+\delta\approx 1$
# * $f(1-\delta)=1-\delta\approx 1$
#
# Therefore
# * $\lim_{x\to 1}f(x)=1$
#
# Note that
# * $\lim_{x\to 1}f(x)\neq f(1)$

# %% [markdown]
# ##Exercise No.2
#
# Find
# * $\lim_{x\to0}\frac{1}{x}=\,?$

# %% [markdown]
# ###Solution
#
# Define
# * $f(x)=\frac{1}{x}$
#
# Calculate $\lim_{x\to0}f(x)$
# * $f(1+\delta)=\frac{1}{\delta}>0$
# * $f(1-\delta)=\frac{-1}{\delta}< 0$
#
# Therefore
# * $\lim_{x\to0}f(x)=\emptyset$

# %% [markdown]
# ##Exercise No.3
#
# Find
# * $\lim_{x\to1}\frac{x^m-1}{x^n-1}=\,?$

# %% [markdown]
# ###Solution
#
# According to L'Hospital Rule
# * $\lim_{x\to a}\frac{f(x)}{g(x)}=\lim_{x\to a}\frac{f'(x)}{g'(x)}$
#
# Implies that
# * $\lim_{x\to1}\frac{x^m-1}{x^n-1}=\frac{mx^{m-1}}{nx^{n-1}}$
#
# Therefore
# * $\lim_{x\to1}\frac{x^m-1}{x^n-1}=\frac{m}{n}$
#
# Note that
# * $\lim_{x\to1}\frac{x^m-1}{x^n-1}\neq \frac{1^m-1}{1^n-1}=\emptyset$

# %% [markdown]
# ##Exercise No.4
#
# Define
# * $f(x)=\begin{Bmatrix}
# \forall x\in\mathbb{R}-0\,:f(x)=\frac{|x|}{x}\\
# f(0)=0
# \end{Bmatrix}$
#
# Find
# * $\lim_{x\to0}f(x)=\,?$

# %% [markdown]
# ###Solution
#
# Given that
# * $\forall \delta\in(0,\infty]\,:f(\delta)=1$
# * $f(-1\cdot \delta)=-1$
#
# Therefore
# * $\lim_{x\to0}f(x)=\emptyset$

# %% [markdown]
# ##Exercise No.5
#
# Find
# * $\lim_{x\to1}\frac{(2x)^{\frac{1}{2}}(x-1)}{|x-1|}=\,?$

# %% [markdown]
# ###Wrong Solution
#
# * $\lim_{x\to1}\frac{\sqrt{2x}(x-1)}{|x-1|}=\,?$
#
# According to L'Hospital Rule
# * $\lim_{x\to a}\frac{f(x)}{g(x)}=\lim_{x\to a}\frac{f'(x)}{g'(x)}$
#
# Given that
# * $\frac{d}{dx}[\sqrt{x}]=\frac{1}{2\sqrt{x}}=\frac{\sqrt{x}}{2x}$
# * $\frac{d}{dx}[\sqrt{2x}]=\frac{\sqrt{2x}}{2x}$
# * $\frac{d}{dx}[x-1]=1$
# * $\frac{d}{dx}[f(x)g(x)]=f(x)g'(x)+g(x)f'(x)$
#
# Implies that
# * $\lim_{x\to1}\frac{\sqrt{2x}(x-1)}{|x-1|}=\lim_{x\to1}\sqrt{2x}+(x-1)(\frac{\sqrt{2x}}{2x})$
# * $\lim_{x\to1}\frac{\sqrt{2x}(x-1)}{|x-1|}=\lim_{x\to1}\sqrt{2x}+(\frac{\sqrt{2}}{2}-\frac{\sqrt{2x}}{2x})$
# * $\lim_{x\to1}\frac{\sqrt{2x}(x-1)}{|x-1|}=\sqrt{2}$
#
# Therefore
# * $\lim_{x\to1}\frac{\sqrt{2x}(x-1)}{|x-1|}=\sqrt{2}$
#
# Reference
# * https://www.cuemath.com/calculus/derivative-of-root-x/

# %% [markdown]
# ###Why This Solution is Wrong?
#
# The right solution is
# * $\lim_{x\to1}\frac{\sqrt{2x}(x-1)}{|x-1|}=\emptyset$
#
# The reason is that
# * $f(x)=|x|\,:f'(x)=1\iff x\neq0$
# * $f(x)=|x|\,:f'(0)=\emptyset$
#
# Thus we cannot directly apply L'Hospital Rule
#
# The another reason is that
# * $\lim_{x\to1^+}\frac{\sqrt{2x}(x-1)}{|x-1|}=\lim_{x\to1}\frac{\sqrt{2x}(x-1)}{(x-1)}=\sqrt{2x}=\sqrt{2}$
# * $\lim_{x\to1^-}\frac{\sqrt{2x}(x-1)}{|x-1|}=\lim_{x\to1}\frac{\sqrt{2x}(x-1)}{-1\cdot (x-1)}=-\sqrt{2x}=-\sqrt{2}$

# %% [markdown]
# ##Exercise No.6
#
# Find
# * $\lim_{x\to1}\frac{|x-1|}{x-1}=\,?$

# %% [markdown]
# ###Solution
#
# Given that
# * $\lim_{x\to1^+}\frac{|x-1|}{x-1}=\lim_{x\to1^+}\frac{x-1}{x-1}=1$
# * $\lim_{x\to1^-}\frac{|x-1|}{x-1}=\lim_{x\to1^-}\frac{-1\cdot(x-1)}{x-1}=-1$
#
# Therefore
# * $\lim_{x\to1}\frac{|x-1|}{x-1}=\emptyset$

# %% [markdown]
# ##Exercise No.7
#
# Evaluate
# * $\lim_{x\to1}\frac{2x}{(x-6)(x-1)}=\,?$

# %% [markdown]
# ###Solution
#
# * $\lim_{x\to1}\frac{2x}{(x-6)(x-1)}=\emptyset$

# %% [markdown]
# #Limit Exercise Part 2: Limit Approach $\infty$
#
# Some function $f(x)$ have limit at infinity if and only if
# * $\lim_{x\to\infty}f(x)=L$
# * $\forall\epsilon>0\,:\exists x\in(0,\infty)\,:|f(x)-L|<\epsilon$
#
# On the other hands, some function $f(x)$ also have limit at minus infinity such that
# * $\lim_{x\to-\infty}f(x)=M$
# * $\forall\epsilon>0\,:\exists x\in(-\infty,0)\,:|f(x)-M|<\epsilon$
#
# ### What is asymptotes?
#
# An asymptote is a straight line that constantly approaches a given curve but does not meet at any infinite distance.
#
# Reference
# * https://www.sfu.ca/math-coursenotes/Math%20157%20Course%20Notes/sec_InfLimits.html
# * https://byjus.com/maths/asymptotes/

# %% [markdown]
# ##Exercise No.1
#
# Define
# * $f(x)=\begin{Bmatrix}
# \forall x< 0\,:f(x)=-2\\
# \forall x\geq 0\,:f(x)=2
# \end{Bmatrix}$
#
# Evaluate
# * $\lim_{x\to\infty}f(x)=\,?$
# * $\lim_{x\to-\infty}f(x)=\,?$

# %% [markdown]
# ###Solution
#
# * $\lim_{x\to\infty}f(x)=2$
# * $\lim_{x\to-\infty}f(x)=-2$

# %% [markdown]
# ##Exercise No.2
#
# Evaluate
# * $\lim_{x\to\infty}\frac{1}{x^2}=\,?$
# * $\lim_{x\to-\infty}\frac{1}{x^2}=\,?$

# %% [markdown]
# ###Solution
#
# * $\lim_{x\to\infty}\frac{1}{x^2}=0$
# * $\lim_{x\to-\infty}\frac{1}{x^2}=0$

# %% [markdown]
# ##Exercise No.3
#
# Evaluate
# * $\lim_{x\to\infty}\frac{2x^2-3x+7}{x^2+47x+1}=\,?$

# %% [markdown]
# ###Solution
#
# Define
# * $f(x)=\frac{2x^2-3x+7}{x^2+47x+1}$
#
# We will find $L$ such that
# * $\forall\epsilon>0\,:\exists x\in\mathbb{R}\,:|f(x)-L|<\epsilon$
#
# Then
# * $|\frac{2x^2-3x+7-Lx^2-47Lx-L}{x^2+47x+1}|<\epsilon$
# * $|\frac{(2-L)x^2-(3+47L)x+7-L}{x^2+47x+1}|<\epsilon$
#
# Suppose that
# * $L=2$
#
# Implies that
# * $|\frac{-97x+5}{x^2+47x+1}|<\epsilon$
#
# Given that
# * $\lim_{x\to\infty}\frac{1}{x}=0$
#
# Therefore
# * $\forall\epsilon>0\,:\exists x\in\mathbb{R}\,:|\frac{-97x+5}{x^2+47x+1}|<\epsilon$
# * $\forall\epsilon>0\,:\exists x\in\mathbb{R}\,:|f(x)-2|<\epsilon$
# * $\lim_{x\to\infty}\frac{2x^2-3x+7}{x^2+47x+1}=2$

# %% [markdown]
# ###Shorter Solution
#
# * $\lim_{x\to\infty}\frac{2x^2-3x+7}{x^2+47x+1}=\frac{2x^2}{x^2}$
#
# * $\lim_{x\to\infty}\frac{2x^2-3x+7}{x^2+47x+1}=2$

# %% [markdown]
# ##Exercise No.3
#
# Evaluate
# * $\lim_{x\to-\infty}\frac{3x}{\sqrt{16x^2-9x}}=\,?$

# %% [markdown]
# ###Solution
#
# $\lim_{x\to-\infty}\frac{3x}{\sqrt{16x^2-9x}}=\lim_{x\to-\infty}\frac{3x\sqrt{16x^2-9x}}{16x^2-9x}$
#
# $\lim_{x\to-\infty}\frac{3x}{\sqrt{16x^2-9x}}=\lim_{x\to-\infty}\frac{3\sqrt{16x^2-9x}}{16x-9}$
#
# $\lim_{x\to-\infty}\frac{3x}{\sqrt{16x^2-9x}}= \lim_{x\to-\infty}\frac{3\cdot 4x}{-4^2x}$
#
# $\lim_{x\to-\infty}\frac{3x}{\sqrt{16x^2-9x}}= \frac{-3}{4}$

# %% [markdown]
# ##Exercise No.4
#
# Evaluate
# * $\lim_{x\to\infty}=\frac{-3x^2+7}{x}=\,?$

# %% [markdown]
# ###Solution
#
# Define
# * $f(x)=\frac{-3x^2+7}{x}=-3x+\frac{7}{x}$
#
# We need to find $L$ such that
# * $\forall\epsilon>0\,:\exists x\in(0,\infty)\,:|f(x)-L|<\epsilon$
#
# Note that
# * $f(0)=\emptyset$
# * $f(1)=-3+7=4$
# * $f(2)=-6+3.5=-2.5$
# * $\lim_{x\to\infty}\frac{1}{x}=0$
# * $\lim_{x\to\infty}-x=-\infty$
#
# Therefore
# * $L=\emptyset$
# * $\lim_{x\to\infty}=\frac{-3x^2+7}{x}=\emptyset$

# %% [markdown]
# #Continuous Function
#
# The function $f(x)$ is continuous on point $a$ and interval $[x_0,x_1]$ if it satisfy 4 properties
# 1. It is defined on $a$
# * $f(a)\in\mathbb{R}$
# 2. Its limit is defined on $a$
# * $\lim_{x\to a}f(x)\in\mathbb{R}$
# 3. $f(a)$ is equal to its limit on $a$
# * $\lim_{x\to a}f(x)=f(a)$
# 4. $\forall x\in [x_0,x_1]$
# * $\forall\epsilon>0\,:\exists\delta>0\,:|x-a|<\delta\implies|f(x)-f(a)|<\epsilon$
#
# Reference
# * https://brilliant.org/wiki/continuous-functions/

# %% [markdown]
# ##Exercise No.1
#
# Check if this function is continuous around point $(3,f(3))$
# * $f(x)=\begin{Bmatrix}
# \forall x< 3\,:f(x)=2x+1\\
# \forall x\geq3\,:f(x)=3x-2\\
# \end{Bmatrix}$

# %% [markdown]
# ###Solution
#
# Given that
# * $f(3)=7$
# * $2\cdot 3+1=7$
#
# Therefore
# * $f(x)$ is continuous around point $(3,f(3))$

# %% [markdown]
# ##Exercise No.2
#
# Check if this function is continuous around point $(2,f(2))$
# * $f(x)=\begin{Bmatrix}
# \forall x< 2\,:f(x)=x+1\\
# f(2)=4\\
# \forall x> 2\,:f(x)=2x-1\\
# \end{Bmatrix}$

# %% [markdown]
# ###Solution
#
# Given that
# * $2+1=3$
# * $2\cdot 2-1=3$
#
# Implies that
# * $\lim_{x\to 2}f(x)=3\neq f(2)=4$
#
# Therefore
# * $f(x)$ is not continuous around point $(2,f(2))$

# %% [markdown]
# #Type of Discontinuity

# %% [markdown]
# ##Removable Discontinuity

# %% [markdown]
# ![Removable.png](data:image/png;base64,...)

# %% [markdown]
# **About the Image**
#
# $f(x)$ have Removable Discontinuity at $x=a$ then
# * $\lim_{x\to a}f(x)\neq f(a)$
# * Where $f(a)=\emptyset$ or $f(a)\in\mathbb{R}$
#
# **Desmos Simulation**
# * https://www.desmos.com/calculator/tnnjzs6gjd
#
# Reference
# * https://www.cuemath.com/calculus/removable-discontinuity/

# %% [markdown]
# ##Jump Discontinuity

# %% [markdown]
# ![jump.png](data:image/png;base64,...)

# %% [markdown]
# **About the Image**
#
# $f(x)$ have Jump Discontinuity at $x=a$ is defined as
# * $\lim_{x\to a}f(x)=\emptyset$
# * $\lim_{x\to a^+}f(x)\neq \lim_{x\to a^-}f(x)$
#
# **Desmos Simulation**
# * https://www.desmos.com/calculator/nxgxwyfesv

# %% [markdown]
# ##Essential Discontinuities

# %% [markdown]
# ![essential.png](data:image/png;base64,...)

# %% [markdown]
# **About the Image**
#
# $f(x)$ have Essential Discontinuities at $x=a$ is defined as
# * $f(a)=\emptyset$
# * $\lim_{x\to a}f(x)=\emptyset$
# * $\sim[\,\forall \epsilon>0\,:\exists \delta>0\,:|x-a|<\delta\implies |f(x)-f(a)|<\epsilon\,]$
#
# This statement can be interpreted as when $x$ approach $a$, $f(x)$ does not approach any value
# * $\exists \epsilon>0\,:\forall \delta>0\,:|x-a|<\delta\land |f(x)-f(a)|\geq\epsilon$
#
# One of the specific example is
# * $f(x)=\sin(\frac{1}{x-a})$
#
# **Desmos Simulation**
# * https://www.desmos.com/calculator/dgajfkrdmv

# %% [markdown]
# ##Vertical Asymptote Discontinuity

# %% [markdown]
# ![tan.png](data:image/png;base64,...)

# %% [markdown]
# **About the Image**
#
# $f(x)$ have Vertical Asymptote Discontinuity at $a$ if one of the statement is true
# 1. $\lim_{x\to a^+}f(x)=\pm\infty$
# 1. $\lim_{x\to a^-}f(x)=\pm\infty$
# 1. $\lim_{x\to a}f(x)=\pm\infty$
#
# Example
# * $f(x)=\frac{1}{x-a}$ where $f(x)$ have discontinuity at $a$
# * $f(x)=\tan(x)$ where $f(x)$ have discontinuity at $x\in\{n\pi+\frac{\pi}{2}|n\in\mathbb{Z}\}$
#
# Desmos Simulation
# * https://www.desmos.com/calculator/eofqyqxem1

# %% [markdown]
# #Uniform Continuity
#
# A function is uniformly continuous if it preserves small distances uniformly across its domain. In other word, suppose that
# * Function is continuous in $[a,b]$
# * $\forall x,y\in[a,b]$
# * $\forall\epsilon>0\,:\exists\delta>0\,:|x-y|<\delta\implies |f(x)-f(y)|<\epsilon$
#
# If $\delta$ is not depending on $\epsilon$ implies that the function is uniformly continuous.
#
# Note that
# * $f(x)$ is uniformly continuous over $[a,b]\implies\,f(x)$ is continuous over $[a,b]$
#
# Reference
# * https://www.tutorocean.com/questions-answers/what-is-an-uniformly-continuous-function
# * https://youtu.be/PA0EJHYymLE?si=7Lbt0KOcLaxWkOTO

# %% [markdown]
# ###Example No.1
#
# Define
# * $f(x)=mx+c$
# * $x,y\in[a,b]$
#
# Then
# * $|f(x)-f(y)|<\epsilon$
# * $|m(x-y)|<\epsilon$
# * $|x-y|<\delta=\frac{\epsilon}{m}$
#
# Implies that
# * $\delta$ is not depending on the $x$ and $y$
# * $f(x)$ is uniform continuous

# %% [markdown]
# ##Note that
#
# * $\sqrt{x}$ is uniform continuous over $[0,\infty)$
# * $\frac{1}{x}$ is uniform continuous over $[2,\infty)$
# * $\frac{1}{x}$ is not uniform continuous over $(0,1]$
#
# However I will prove the result in the future project.

# %% [markdown]
# #Bonus Exercise

# %% [markdown]
# ##Exercise No.1
#
# $\lim_{x\to\pi}\frac{\sin(x)-0}{x-\pi}=\,?$

# %% [markdown]
# ###Solution
#
# $\lim_{x\to\pi}\frac{\sin(x)-0}{x-\pi}=\frac{d}{d\pi}[\sin(\pi)]=\cos(\pi)=-1$
